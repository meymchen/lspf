# %% [markdown]
# # lspf Notebook debugging
#
# Hover over text in either code cell to inspect its Notebook and Document versions.
# Edit, insert, delete, or move cells, then save. The **lspf notebooks** output channel records lifecycle hooks.
# No kernel or cell execution is needed.

# %%
message = '🙂 first cell'
print(message)

# %%
message = 'second cell'
print(message)
